# %% [markdown]
# ASSIGNMENT_WEEK_1

# %% [markdown]
# 1. Create and print a 2-dimensional NumPy array of shape (5, 5) filled with random* integers between 1 and 100

# %%
import numpy as np
matrix=np.random.randint(1,100,size=(5,5))
matrix
# Out:
# array([[ 6,  7, 51,  4, 97],
#        [18,  6, 80, 19, 91],
#        [24, 52, 22, 36, 75],
#        [97,  4, 68, 24, 27],
#        [98, 28, 63, 29, 45]])

# %%
print(matrix)
# Out:
# [[ 6  7 51  4 97]
#  [18  6 80 19 91]
#  [24 52 22 36 75]
#  [97  4 68 24 27]
#  [98 28 63 29 45]]

# %% [markdown]
# a. Extract and print the middle element of the array using NumPy indexing.

# %%
middle_element=matrix[2,2]  
print(middle_element)
# Out:
# 22

# %% [markdown]
# b. Calculate and print the mean of each row of the array.

# %%
mean=matrix.mean(axis=1)
print("mean of each row of the array:",mean)
# Out:
# mean of each row of the array: [33.  42.8 41.8 44.  52.6]

# %% [markdown]
# c. Create a new array that contains only the elements from the original array that are greater than the overall mean of the array

# %%
mean=matrix.mean()
print("overall mean of the array:",mean)
# Out:
# overall mean of the array: 42.84

# %%
new_arr=matrix[matrix>mean]
new_arr
# Out:
# array([51, 97, 80, 91, 52, 75, 97, 68, 98, 63, 45])

# %% [markdown]
# d. Write a Python function numpy_spiral_order(matrix) that takes a NumPy matrix and returns a list containing the elements visited in a spiral order

# %%
def spiral_order(matrix):

    result = []
    top, bottom, left, right = 0, matrix.shape[0] - 1, 0, matrix.shape[1] - 1

    while top <= bottom and left <= right:
        # Traverse from left to right
        for j in range(left, right + 1):
            result.append(matrix[top, j])
        top += 1

        # Traverse from top to bottom
        for i in range(top, bottom + 1):
            result.append(matrix[i, right])
        right -= 1

        if top <= bottom:
            # Traverse from right to left
            for j in range(right, left - 1, -1):
                result.append(matrix[bottom, j])
            bottom -= 1

        if left <= right:
            # Traverse from bottom to top
            for i in range(bottom, top - 1, -1):
                result.append(matrix[i, left])
            left += 1

    return result
res = spiral_order(matrix)
print("spiral_order:",res)
# Out:
# spiral_order: [6, 7, 51, 4, 97, 91, 75, 27, 45, 29, 63, 28, 98, 97, 24, 18, 6, 80, 19, 36, 24, 68, 4, 52, 22]

# %% [markdown]
# Now let’s try to apply Python libraries on a dataset of Video Game Sales!

# %% [markdown]
# 2. Create a Jupyter Notebook or a Google Colab Notebook, download the dataset in the drive link, and solve the following questions using the required Python libraries

# %% [markdown]
# a. Add a column of ‘global_sales’ showing the total sales of all the different regions to the data frame and sort (highest first) and print the DataFrame according to it.

# %%
import pandas as pd
csv=pd.read_csv("C:\\Users\\Rutvik Rathva\\OneDrive\\Desktop\\learner_space_python_DS\\videogamesales.csv")
csv.head()
# Out:
#               Name Platform    Year     Genre   Publisher  NA_Sales  EU_Sales  \
# 0        Asteroids     2600  1980.0   Shooter       Atari      4.00      0.26
# 1  Missile Command     2600  1980.0   Shooter       Atari      2.56      0.17
# 2          Kaboom!     2600  1980.0      Misc  Activision      1.07      0.07
# 3         Defender     2600  1980.0      Misc       Atari      0.99      0.05
# 4           Boxing     2600  1980.0  Fighting  Activision      0.72      0.04
#
#    JP_Sales  Other_Sales
# 0       0.0         0.05
# 1       0.0         0.03
# 2       0.0         0.01
# 3       0.0         0.01
# 4       0.0         0.01

# %%
csv["global_sales"]=csv["NA_Sales"]+csv["EU_Sales"]+csv["JP_Sales"]+csv["Other_Sales"]
csv
# Out:
#                                              Name Platform    Year     Genre  \
# 0                                       Asteroids     2600  1980.0   Shooter
# 1                                 Missile Command     2600  1980.0   Shooter
# 2                                         Kaboom!     2600  1980.0      Misc
# 3                                        Defender     2600  1980.0      Misc
# 4                                          Boxing     2600  1980.0  Fighting
# ...                                           ...      ...     ...       ...
# 16578           WRC: FIA World Rally Championship     X360     NaN    Racing
# 16579           WRC: FIA World Rally Championship       PC     NaN    Racing
# 16580  Writing and Speaking Beautiful Japanese DS       DS     NaN      Misc
# 16581  Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii     NaN    Racing
# 16582                    Zero: Tsukihami no Kamen      Wii     NaN    Action
#
# ...

# %%
csv.tail()
# Out:
#                                              Name Platform  Year   Genre  \
# 16578           WRC: FIA World Rally Championship     X360   NaN  Racing
# 16579           WRC: FIA World Rally Championship       PC   NaN  Racing
# 16580  Writing and Speaking Beautiful Japanese DS       DS   NaN    Misc
# 16581  Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii   NaN  Racing
# 16582                    Zero: Tsukihami no Kamen      Wii   NaN  Action
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 16578  Black Bean Games       0.0      0.10      0.00         0.02
# 16579  Black Bean Games       0.0      0.01      0.00         0.00
# 16580           Unknown       0.0      0.00      0.02         0.00
# 16581           Unknown       0.0      0.00      0.02         0.00
# 16582          Nintendo       0.0      0.00      0.08         0.00
#
#        global_sales
# 16578          0.12
# 16579          0.01
# 16580          0.02
# 16581          0.02
# ...

# %%
new_csv=csv.sort_values(by="global_sales",ascending=False)
new_csv.head()
# Out:
#                           Name Platform    Year         Genre Publisher  \
# 6109                Wii Sports      Wii  2006.0        Sports  Nintendo
# 122          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 8315            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 9743         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 705   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  global_sales
# 6109     41.49     29.02      3.77         8.46         82.74
# 122      29.08      3.58      6.81         0.77         40.24
# 8315     15.85     12.88      3.79         3.31         35.83
# 9743     15.75     11.01      3.28         2.96         33.00
# 705      11.27      8.89     10.22         1.00         31.38

# %%
new_csv.tail()
# Out:
#                                                    Name Platform    Year  \
# 10978       Military History: Commander - Europe at War       DS  2009.0
# 7971            Puzzle Quest: Challenge of the Warlords      PSP  2007.0
# 7972                         Race Driver: Create & Race       DS  2007.0
# 10854                                   Cross Edge Dash     X360  2009.0
# 9650   SCORE International Baja 1000: The Official Game      PS2  2008.0
#
#               Genre            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 10978      Strategy  Slitherine Software      0.00      0.01      0.00
# 7971         Puzzle          D3Publisher      0.01      0.00      0.00
# 7972         Racing          Codemasters      0.01      0.00      0.00
# 10854  Role-Playing        Compile Heart      0.00      0.00      0.01
# 9650         Racing           Activision      0.00      0.00      0.00
#
#        Other_Sales  global_sales
# 10978          0.0          0.01
# ...

# %%
c=new_csv.reset_index(drop=True)

# %%
print(c)
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16578       Military History: Commander - Europe at War       DS  2009.0
# 16579           Puzzle Quest: Challenge of the Warlords      PSP  2007.0
# 16580                        Race Driver: Create & Race       DS  2007.0
# 16581                                   Cross Edge Dash     X360  2009.0
# 16582  SCORE International Baja 1000: The Official Game      PS2  2008.0
#
#               Genre            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# b. Display a plot of the total number of copies sold of each genre globally.

# %%
import matplotlib.pyplot as plt
x=csv['Genre']
y=csv['global_sales']
plt.xlabel("Genre")
plt.ylabel("total numbers of copies sold")
plt.title("plot of the total number of copies sold of each genre globally")
plt.xticks(rotation=45)
plt.bar(x,y)
plt.show()

# %% [markdown]
# c. Filter out only the GTA games and display the following as a DataFrame :
#      1.their name
#      2.the platform they were released on
#      3.the year they were released in
#      4.the sum of sales in only Europe and Japan

# %%
gta_games_Adventure=csv[csv["Genre"].str.contains("Adventure")]
gta_games_Adventure
# Out:
#                                                     Name Platform    Year  \
# 100                                                Pengo     2600  1983.0
# 157                      Zelda II: The Adventure of Link      NES  1987.0
# 226                          Metroid II: Return of Samus       GB  1991.0
# 258                     The Legend of the Mystical Ninja     SNES  1991.0
# 262                   Super Mario Land 2: 6 Golden Coins       GB  1992.0
# ...                                                  ...      ...     ...
# 16455                                         The Hidden      3DS     NaN
# 16514                        Hakuouki: Shinsengumi Kitan      PS3     NaN
# 16526                          B.L.U.E.: Legend of Water       PS     NaN
# 16560                           Runaway: A Twist of Fate       DS     NaN
# 16572  Umineko no Naku Koro ni San: Shinjitsu to Gens...      PS3     NaN
#
#            Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
gta_games_Action=csv[csv["Genre"].str.contains("Action")]
gta_games_Action
# Out:
#                                                     Name Platform    Year  \
# 6                                                Freeway     2600  1980.0
# 10                                               Frogger     2600  1981.0
# 12                           E.T.: The Extra Terrestrial     2600  1981.0
# 21                                            Spider-Man     2600  1981.0
# 22                                      Custer's Revenge     2600  1981.0
# ...                                                  ...      ...     ...
# 16542                   Fullmetal Alchemist: Brotherhood      PSP     NaN
# 16548                                       Housekeeping       DS     NaN
# 16569  The Legend of Zelda: The Minish Cap(weekly JP ...      GBA     NaN
# 16570                                         The Smurfs      3DS     NaN
# 16582                           Zero: Tsukihami no Kamen      Wii     NaN
#
#         Genre     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
gta_games=pd.concat([gta_games_Adventure,gta_games_Action])
gta_games
# Out:
#                                                     Name Platform    Year  \
# 100                                                Pengo     2600  1983.0
# 157                      Zelda II: The Adventure of Link      NES  1987.0
# 226                          Metroid II: Return of Samus       GB  1991.0
# 258                     The Legend of the Mystical Ninja     SNES  1991.0
# 262                   Super Mario Land 2: 6 Golden Coins       GB  1992.0
# ...                                                  ...      ...     ...
# 16542                   Fullmetal Alchemist: Brotherhood      PSP     NaN
# 16548                                       Housekeeping       DS     NaN
# 16569  The Legend of Zelda: The Minish Cap(weekly JP ...      GBA     NaN
# 16570                                         The Smurfs      3DS     NaN
# 16582                           Zero: Tsukihami no Kamen      Wii     NaN
#
#            Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
gta_games["EU_sales+JP_sales"]=gta_games["EU_Sales"]+gta_games["JP_Sales"]
gta_games
# Out:
#                                                     Name Platform    Year  \
# 100                                                Pengo     2600  1983.0
# 157                      Zelda II: The Adventure of Link      NES  1987.0
# 226                          Metroid II: Return of Samus       GB  1991.0
# 258                     The Legend of the Mystical Ninja     SNES  1991.0
# 262                   Super Mario Land 2: 6 Golden Coins       GB  1992.0
# ...                                                  ...      ...     ...
# 16542                   Fullmetal Alchemist: Brotherhood      PSP     NaN
# 16548                                       Housekeeping       DS     NaN
# 16569  The Legend of Zelda: The Minish Cap(weekly JP ...      GBA     NaN
# 16570                                         The Smurfs      3DS     NaN
# 16582                           Zero: Tsukihami no Kamen      Wii     NaN
#
#            Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
gta_games[["Name","Platform","Year","EU_sales+JP_sales"]].reset_index(drop=True)
# Out:
#                                                    Name Platform    Year  \
# 0                                                 Pengo     2600  1983.0
# 1                       Zelda II: The Adventure of Link      NES  1987.0
# 2                           Metroid II: Return of Samus       GB  1991.0
# 3                      The Legend of the Mystical Ninja     SNES  1991.0
# 4                    Super Mario Land 2: 6 Golden Coins       GB  1992.0
# ...                                                 ...      ...     ...
# 4591                   Fullmetal Alchemist: Brotherhood      PSP     NaN
# 4592                                       Housekeeping       DS     NaN
# 4593  The Legend of Zelda: The Minish Cap(weekly JP ...      GBA     NaN
# 4594                                         The Smurfs      3DS     NaN
# 4595                           Zero: Tsukihami no Kamen      Wii     NaN
#
#       EU_sales+JP_sales
# 0                  0.02
# 1                  2.11
# ...

# %%
gta_games[["global_sales"]]
# Out:
#        global_sales
# 100            0.40
# 157            4.38
# 226            1.76
# 258            0.48
# 262           11.18
# ...             ...
# 16542          0.03
# 16548          0.04
# 16569          0.28
# 16570          0.01
# 16582          0.08
#
# [4596 rows x 1 columns]

# %% [markdown]
# d. Display a pie chart of the total sales of all Grand Theft Auto games combined in North America, Europe, Japan, and other sales.

# %%
import matplotlib.pyplot as plt
total_sales={"North_America":gta_games["NA_Sales"].sum(),"Europe":gta_games["EU_Sales"].sum(),"Japan":gta_games["JP_Sales"].sum(),"other_sales":gta_games["Other_Sales"].sum()}
regions= list(total_sales.keys())
sales = list(total_sales.values())
plt.pie(sales,labels=regions,autopct='%.2f%%')
plt.show()
